# %% [markdown]
# #SQL Exercises
# <font color = red> **First step:** </font> Go to https://www.w3schools.com/sql/exercise.asp?filename=exercise_select1 and do the 3 SQL SELECT and 5 SQL WHERE exercises. Take a screenshot with the snipping tool that shows some of the checkmarks and the top part that says Completed 8 of the 52 exercises and paste in the image using CTRL-v here. Refer to the SQL [tutorials](https://www.w3schools.com/sql/sql_where.asp) or [slides](https://docs.google.com/presentation/d/1lNTg91_cmSLA55KDQ053k_Le6KF0ebwt/edit?usp=sharing&ouid=103318494975202631994&rtpof=true&sd=true) if you need help.

# %% [markdown]
# Paste in your screenshot here using  CTRL-v.

# %% [markdown]
# #Working with Databases in Python and Pandas
# <font color = red> **Important!** </font> First, download SQLlite database called [flights.db](https://drive.google.com/file/d/1T2Nf5vGq6fJfM7x_U8N5PwZVtzZvteru/view?usp=sharing). Click on the folder on the left, and click on upload and upload the flights.db file. Then, run the following code to connect to the flights.db. You wil need to upload it everytime you open this file.

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect("flights.db")
conn

# %% [markdown]
# The database contains three tables — `airports`, `airlines`, and `routes`. In Python Pandas, you can do a SQL Query and save the results in a data frame like below!

# %%
airlines = pd.read_sql_query("SELECT * FROM airlines;", conn)
airlines
# Out:
#       index     id                                          name  \
# 0         0      1                                Private flight
# 1         1      2                                   135 Airways
# 2         2      3                                 1Time Airline
# 3         3      4  2 Sqn No 1 Elementary Flying Training School
# 4         4      5                               213 Flight Unit
# ...     ...    ...                                           ...
# 6043   6043  19828                                    Vuela Cuba
# 6044   6044  19830                                 All Australia
# 6045   6045  19831                                    Fly Europa
# 6046   6046  19834                                   FlyPortugal
# 6047   6047  19845                          FTI Fluggesellschaft
#
#               alias  iata  icao     callsign         country active
# 0                \N     -  None         None            None      Y
# ...

# %%
airports = pd.read_sql_query("SELECT * FROM airports;", conn)
airports
# Out:
#       index    id                               name             city  \
# 0         0     1                             Goroka           Goroka
# 1         1     2                             Madang           Madang
# 2         2     3                        Mount Hagen      Mount Hagen
# 3         3     4                             Nadzab           Nadzab
# 4         4     5         Port Moresby Jacksons Intl     Port Moresby
# ...     ...   ...                                ...              ...
# 8102   8102  9537    Mansons Landing Water Aerodrome  Mansons Landing
# 8103   8103  9538               Port McNeill Airport     Port McNeill
# 8104   8104  9539       Sullivan Bay Water Aerodrome     Sullivan Bay
# 8105   8105  9540               Deer Harbor Seaplane      Deer Harbor
# 8106   8106  9541  San Diego Old Town Transit Center        San Diego
#
#                country code  icao   latitude    longitude altitude offset dst  \
# ...

# %% [markdown]
# <font color=red>Write code that reads in the routes table into a variable called `routes` using a SELECT * query.</font>

# %%
routes = pd.read_sql_query("SELECT * FROM routes;", conn)
routes
# Out:
#        index airline airline_id source source_id dest dest_id codeshare stops  \
# 0          0      2B        410    AER      2965  KZN    2990      None     0
# 1          1      2B        410    ASF      2966  KZN    2990      None     0
# 2          2      2B        410    ASF      2966  MRV    2962      None     0
# 3          3      2B        410    CEK      2968  KZN    2990      None     0
# 4          4      2B        410    CEK      2968  OVB    4078      None     0
# ...      ...     ...        ...    ...       ...  ...     ...       ...   ...
# 67658  67658      ZL       4178    WYA      6334  ADL    3341      None     0
# 67659  67659      ZM      19016    DME      4029  FRU    2912      None     0
# 67660  67660      ZM      19016    FRU      2912  DME    4029      None     0
# 67661  67661      ZM      19016    FRU      2912  OSS    2913      None     0
# 67662  67662      ZM      19016    OSS      2913  FRU    2912      None     0
#
#       equipment
# ...

# %% [markdown]
# Let's try a SQL query with a WHERE clause to pull out just the airports in the United States.

# %%
us_airports = pd.read_sql_query("SELECT * FROM airports WHERE country = 'United States';", conn)
us_airports
# Out:
#       index    id                               name               city  \
# 0       318  6891              Putnam County Airport        Greencastle
# 1      1104  6890         Dowagiac Municipal Airport           Dowagiac
# 2      1121  6889        Cambridge Municipal Airport          Cambridge
# 3      1470  6885     Door County Cherryland Airport       Sturgeon Bay
# 4      1507  6884       Shoestring Aviation Airfield       Stewartstown
# ...     ...   ...                                ...                ...
# 1692   8079  9514                     Ferry Terminal             Valdez
# 1693   8090  9525                         Ferry Dock  Bainbridge Island
# 1694   8098  9533                 Chatsworth Station         Chatsworth
# 1695   8105  9540               Deer Harbor Seaplane        Deer Harbor
# 1696   8106  9541  San Diego Old Town Transit Center          San Diego
#
#             country  code  icao    latitude    longitude altitude offset dst  \
# ...

# %% [markdown]
# <font color=red>Write a SQL query like above that prints out the **airports** for the city Boston saved in a variable for `boston_airports`.</font>

# %%
boston_airports = pd.read_sql_query("SELECT * FROM airports WHERE city = 'Boston';", conn)
boston_airports
# Out:
#    index    id                                name    city        country  \
# 0   3349  3448  General Edward Lawrence Logan Intl  Boston  United States
# 1   6539  7966                Boston South Station  Boston  United States
# 2   7614  9049             Boston Back Bay Station  Boston  United States
# 3   7898  9333                Boston North Station  Boston  United States
# 4   7902  9337                          Long Wharf  Boston  United States
#
#    code  icao   latitude   longitude altitude offset dst          timezone
# 0   BOS  KBOS  42.364347  -71.005181       19     -5   A  America/New_York
# 1  None  BOST      42.35    -71.0558        0     -5   A  America/New_York
# 2   ZTY    \N    42.3478     -71.075       20     -5   A  America/New_York
# 3  None    \N  42.366235  -71.061122      141     -5   A  America/New_York
# 4  None    \N   42.36024  -71.048105       16     -5   A  America/New_York

# %% [markdown]
# <font color=red>Write a SQL query like above that prints out the **routes** where the source is 'BOS' (all flights from Boston).</font>

# %%
boston_routes = pd.read_sql_query("SELECT * FROM routes WHERE source = 'BOS';", conn)
boston_routes
# Out:
#      index airline airline_id source source_id dest dest_id codeshare stops  \
# 0     3620      9K       1629    BOS      3448  ACK    3517      None     0
# 1     3621      9K       1629    BOS      3448  ALB    3864      None     0
# 2     3622      9K       1629    BOS      3448  AUG    3701      None     0
# 3     3623      9K       1629    BOS      3448  BHB    4025      None     0
# 4     3624      9K       1629    BOS      3448  HYA    4278      None     0
# ..     ...     ...        ...    ...       ...  ...     ...       ...   ...
# 207  63566      WN       4547    BOS      3448  MCI    3458      None     0
# 208  63567      WN       4547    BOS      3448  MCO    3878      None     1
# 209  63568      WN       4547    BOS      3448  MDW    3747      None     0
# 210  63569      WN       4547    BOS      3448  MKE    3717      None     0
# 211  63570      WN       4547    BOS      3448  STL    3678      None     0
#
#     equipment
# 0         CNA
# 1         CNA
# ...

# %% [markdown]
# You may have noticed that the `routes` table has foreign keys for `airline_id` and `source_id` and `dest_id` instead of the airlines and airport names. You have to look these up in the other tables. Here's a SQL query that joins together the routes and the airports and the airlines tables so that you can see which airlines fly to which airports.

# %%
flights = pd.read_sql_query("SELECT * FROM routes JOIN airports ON airports.id = routes.dest_id JOIN airlines ON airlines.id = routes.airline_id", conn)
flights
# Out:
#        index airline airline_id source source_id dest dest_id codeshare stops  \
# 0          0      2B        410    AER      2965  KZN    2990      None     0
# 1          1      2B        410    ASF      2966  KZN    2990      None     0
# 2          2      2B        410    ASF      2966  MRV    2962      None     0
# 3          3      2B        410    CEK      2968  KZN    2990      None     0
# 4          4      2B        410    CEK      2968  OVB    4078      None     0
# ...      ...     ...        ...    ...       ...  ...     ...       ...   ...
# 66751  67658      ZL       4178    WYA      6334  ADL    3341      None     0
# 66752  67659      ZM      19016    DME      4029  FRU    2912      None     0
# 66753  67660      ZM      19016    FRU      2912  DME    4029      None     0
# 66754  67661      ZM      19016    FRU      2912  OSS    2913      None     0
# 66755  67662      ZM      19016    OSS      2913  FRU    2912      None     0
#
# ...

# %% [markdown]
# # Pandas Dataframes
#
# Now that you have data in data frames, you can just use python pandas code to look at the data too. For example, here are the airlines in the country Japan. Review https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/03_subset_data.html

# %%
airlines[ airlines.country == 'Japan']
# Out:
#       index     id                             name                   alias  \
# 70       70     71                 Advanced Air Co.                      \N
# 247     247    248                 ANA & JP Express                      \N
# 249     249    250                        Air Japan                      \N
# 265     265    266      Air Nippon Network Co. Ltd.                      \N
# 323     323    324               All Nippon Airways  ANA All Nippon Airways
# 335     335    336                       Air Nippon                      \N
# 778     778    779                      Air Central                      \N
# 1104   1104   1105                     AVC Airlines                      \N
# 1124   1124   1126                         Air Next                      \N
# 1316   1316   1318                       airtransse                      \N
# 2353   2353   2355              First Air Transport                      \N
# ...

# %% [markdown]
# <font color=red>Write Python code like above using the flights dataframe to list the flights into the city Boston.</font>

# %%
flights[ flights.city == 'Boston']
# Out:
#        index airline airline_id source source_id dest dest_id codeshare stops  \
# 3393    3605      9K       1629    ACK      3517  BOS    3448      None     0
# 3397    3609      9K       1629    ALB      3864  BOS    3448      None     0
# 3400    3612      9K       1629    AUG      3701  BOS    3448      None     0
# 3402    3614      9K       1629    BHB      4025  BOS    3448      None     0
# 3433    3645      9K       1629    HYA      4278  BOS    3448      None     0
# ...      ...     ...        ...    ...       ...  ...     ...       ...   ...
# 63279  64015      WN       4547    MCI      3458  BOS    3448      None     0
# 63306  64042      WN       4547    MCO      3878  BOS    3448      None     1
# 63349  64085      WN       4547    MDW      3747  BOS    3448      None     0
# 63413  64149      WN       4547    MKE      3717  BOS    3448      None     0
# 63747  64483      WN       4547    STL      3678  BOS    3448      None     0
#
# ...

# %% [markdown]
# Here's some code that groups the airports by country and then counts the number of airports in each country (https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/06_calculate_statistics.html). <br>
# <font color=red>Find out which country has the most airports by using sort_values('id') on this groupby/count dataframe.</font>

# %%
airports.groupby('country').count().sort_values('id', ascending=False)
# Out:
#                          index    id  name  city  code  icao  latitude  \
# country
# United States             1697  1697  1697  1697  1459  1696      1697
# Canada                     435   435   435   435   368   435       435
# Germany                    321   321   321   321   128   321       321
# Australia                  263   263   263   263   215   263       263
# Russia                     249   249   249   249   147   249       249
# ...                        ...   ...   ...   ...   ...   ...       ...
# Norfolk Island               1     1     1     1     1     1         1
# Barbados                     1     1     1     1     1     1         1
# Benin                        1     1     1     1     1     1         1
# Myanmar                      1     1     1     1     1     1         1
# Cocos (Keeling) Islands      1     1     1     1     1     1         1
#
#                          longitude  altitude  offset   dst  timezone
# country
# ...

# %% [markdown]
# #Map Visualization
# <font color=red>Change `scope` to "north america" or "europe" and see what happens.</font>

# %%
import plotly.express as px
fig = px.scatter_geo(airports,
                     lat="latitude", lon="longitude",
                     hover_name="name", scope = "europe",
                     template='plotly', projection="natural earth",
                     title="Airports")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Click on Share to grab the link and share it in the Moodle assignment for this week.
